# %%
import numpy as np 
import pandas as pd

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# /kaggle/input/climate-fever-dataset/climate-fever.json
# /kaggle/input/climate-fever-dataset/climate-fever.csv
# /kaggle/input/climate-fever-dataset/climate-fever.jsonl

# %%
# !pip install farm-haystack[colab]
# !pip install datasets
# Out:
# Collecting farm-haystack[colab]
#   Downloading farm_haystack-1.25.0-py3-none-any.whl.metadata (27 kB)
# Collecting boilerpy3 (from farm-haystack[colab])
#   Downloading boilerpy3-1.0.7-py3-none-any.whl.metadata (5.8 kB)
# Collecting events (from farm-haystack[colab])
#   Downloading Events-0.5-py3-none-any.whl.metadata (3.9 kB)
# Requirement already satisfied: httpx in /opt/conda/lib/python3.10/site-packages (from farm-haystack[colab]) (0.27.0)
# Requirement already satisfied: jsonschema in /opt/conda/lib/python3.10/site-packages (from farm-haystack[colab]) (4.20.0)
# Collecting lazy-imports==0.3.1 (from farm-haystack[colab])
#   Downloading lazy_imports-0.3.1-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: more-itertools in /opt/conda/lib/python3.10/site-packages (from farm-haystack[colab]) (10.2.0)
# Requirement already satisfied: networkx in /opt/conda/lib/python3.10/site-packages (from farm-haystack[colab]) (3.2.1)
# Requirement already satisfied: pandas in /opt/conda/lib/python3.10/site-packages (from farm-haystack[colab]) (2.1.4)
# Requirement already satisfied: pillow in /opt/conda/lib/python3.10/site-packages (from farm-haystack[colab]) (9.5.0)
# Requirement already satisfied: platformdirs in /opt/conda/lib/python3.10/site-packages (from farm-haystack[colab]) (4.2.0)
# Collecting posthog (from farm-haystack[colab])
#   Downloading posthog-3.5.0-py2.py3-none-any.whl.metadata (2.0 kB)
# Collecting prompthub-py==4.0.0 (from farm-haystack[colab])
#   Downloading prompthub_py-4.0.0-py3-none-any.whl.metadata (2.2 kB)
# Collecting pydantic<2 (from farm-haystack[colab])
#   Downloading pydantic-1.10.14-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (150 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 150.2/150.2 kB 8.5 MB/s eta 0:00:00
# Collecting quantulum3 (from farm-haystack[colab])
#   Downloading quantulum3-0.9.0-py3-none-any.whl.metadata (14 kB)
# Collecting rank-bm25 (from farm-haystack[colab])
#   Downloading rank_bm25-0.2.2-py3-none-any.whl.metadata (3.2 kB)
# Requirement already satisfied: requests in /opt/conda/lib/python3.10/site-packages (from farm-haystack[colab]) (2.31.0)
# Collecting requests-cache<1.0.0 (from farm-haystack[colab])
#   Downloading requests_cache-0.9.8-py3-none-any.whl.metadata (8.7 kB)
# Collecting scikit-learn>=1.3.0 (from farm-haystack[colab])
#   Downloading scikit_learn-1.4.1.post1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (11 kB)
# Collecting sseclient-py (from farm-haystack[colab])
#   Downloading sseclient_py-1.8.0-py2.py3-none-any.whl.metadata (2.0 kB)
# Requirement already satisfied: tenacity in /opt/conda/lib/python3.10/site-packages (from farm-haystack[colab]) (8.2.3)
# Collecting tiktoken>=0.5.1 (from farm-haystack[colab])
#   Downloading tiktoken-0.6.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.6 kB)
# Requirement already satisfied: tqdm in /opt/conda/lib/python3.10/site-packages (from farm-haystack[colab]) (4.66.1)
# Collecting transformers==4.37.2 (from farm-haystack[colab])
#   Downloading transformers-4.37.2-py3-none-any.whl.metadata (129 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 129.4/129.4 kB 7.7 MB/s eta 0:00:00
# Collecting pillow (from farm-haystack[colab])
#   Downloading Pillow-9.0.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (7.6 kB)
# Requirement already satisfied: pyyaml<7.0,>=6.0 in /opt/conda/lib/python3.10/site-packages (from prompthub-py==4.0.0->farm-haystack[colab]) (6.0.1)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from transformers==4.37.2->farm-haystack[colab]) (3.13.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.19.3 in /opt/conda/lib/python3.10/site-packages (from transformers==4.37.2->farm-haystack[colab]) (0.20.3)
# Requirement already satisfied: numpy>=1.17 in /opt/conda/lib/python3.10/site-packages (from transformers==4.37.2->farm-haystack[colab]) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.10/site-packages (from transformers==4.37.2->farm-haystack[colab]) (21.3)
# Requirement already satisfied: regex!=2019.12.17 in /opt/conda/lib/python3.10/site-packages (from transformers==4.37.2->farm-haystack[colab]) (2023.12.25)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in /opt/conda/lib/python3.10/site-packages (from transformers==4.37.2->farm-haystack[colab]) (0.15.2)
# Requirement already satisfied: safetensors>=0.4.1 in /opt/conda/lib/python3.10/site-packages (from transformers==4.37.2->farm-haystack[colab]) (0.4.2)
# Requirement already satisfied: typing-extensions>=4.2.0 in /opt/conda/lib/python3.10/site-packages (from pydantic<2->farm-haystack[colab]) (4.9.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests->farm-haystack[colab]) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests->farm-haystack[colab]) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests->farm-haystack[colab]) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests->farm-haystack[colab]) (2024.2.2)
# Requirement already satisfied: appdirs>=1.4.4 in /opt/conda/lib/python3.10/site-packages (from requests-cache<1.0.0->farm-haystack[colab]) (1.4.4)
# Requirement already satisfied: attrs>=21.2 in /opt/conda/lib/python3.10/site-packages (from requests-cache<1.0.0->farm-haystack[colab]) (23.2.0)
# Collecting cattrs>=22.2 (from requests-cache<1.0.0->farm-haystack[colab])
#   Downloading cattrs-23.2.3-py3-none-any.whl.metadata (10 kB)
# Collecting url-normalize>=1.4 (from requests-cache<1.0.0->farm-haystack[colab])
#   Downloading url_normalize-1.4.3-py2.py3-none-any.whl.metadata (3.1 kB)
# Requirement already satisfied: scipy>=1.6.0 in /opt/conda/lib/python3.10/site-packages (from scikit-learn>=1.3.0->farm-haystack[colab]) (1.11.4)
# Requirement already satisfied: joblib>=1.2.0 in /opt/conda/lib/python3.10/site-packages (from scikit-learn>=1.3.0->farm-haystack[colab]) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/conda/lib/python3.10/site-packages (from scikit-learn>=1.3.0->farm-haystack[colab]) (3.2.0)
# Requirement already satisfied: anyio in /opt/conda/lib/python3.10/site-packages (from httpx->farm-haystack[colab]) (4.2.0)
# Requirement already satisfied: httpcore==1.* in /opt/conda/lib/python3.10/site-packages (from httpx->farm-haystack[colab]) (1.0.4)
# Requirement already satisfied: sniffio in /opt/conda/lib/python3.10/site-packages (from httpx->farm-haystack[colab]) (1.3.0)
# Requirement already satisfied: h11<0.15,>=0.13 in /opt/conda/lib/python3.10/site-packages (from httpcore==1.*->httpx->farm-haystack[colab]) (0.14.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /opt/conda/lib/python3.10/site-packages (from jsonschema->farm-haystack[colab]) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in /opt/conda/lib/python3.10/site-packages (from jsonschema->farm-haystack[colab]) (0.32.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /opt/conda/lib/python3.10/site-packages (from jsonschema->farm-haystack[colab]) (0.16.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/lib/python3.10/site-packages (from pandas->farm-haystack[colab]) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.10/site-packages (from pandas->farm-haystack[colab]) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /opt/conda/lib/python3.10/site-packages (from pandas->farm-haystack[colab]) (2023.4)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.10/site-packages (from posthog->farm-haystack[colab]) (1.16.0)
# Collecting monotonic>=1.5 (from posthog->farm-haystack[colab])
#   Downloading monotonic-1.6-py2.py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: backoff>=1.10.0 in /opt/conda/lib/python3.10/site-packages (from posthog->farm-haystack[colab]) (2.2.1)
# Collecting inflect (from quantulum3->farm-haystack[colab])
#   Downloading inflect-7.0.0-py3-none-any.whl.metadata (21 kB)
# Collecting num2words (from quantulum3->farm-haystack[colab])
#   Downloading num2words-0.5.13-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: exceptiongroup>=1.1.1 in /opt/conda/lib/python3.10/site-packages (from cattrs>=22.2->requests-cache<1.0.0->farm-haystack[colab]) (1.2.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /opt/conda/lib/python3.10/site-packages (from huggingface-hub<1.0,>=0.19.3->transformers==4.37.2->farm-haystack[colab]) (2024.2.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/conda/lib/python3.10/site-packages (from packaging>=20.0->transformers==4.37.2->farm-haystack[colab]) (3.1.1)
# Requirement already satisfied: docopt>=0.6.2 in /opt/conda/lib/python3.10/site-packages (from num2words->quantulum3->farm-haystack[colab]) (0.6.2)
# Downloading lazy_imports-0.3.1-py3-none-any.whl (12 kB)
# Downloading prompthub_py-4.0.0-py3-none-any.whl (6.9 kB)
# Downloading transformers-4.37.2-py3-none-any.whl (8.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.4/8.4 MB 95.6 MB/s eta 0:00:00:00:0100:01
# Downloading Pillow-9.0.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.3/4.3 MB 83.3 MB/s eta 0:00:00:00:01
# Downloading pydantic-1.10.14-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 83.1 MB/s eta 0:00:00:00:01
# Downloading requests_cache-0.9.8-py3-none-any.whl (48 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.7/48.7 kB 3.1 MB/s eta 0:00:00
# Downloading scikit_learn-1.4.1.post1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (12.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.1/12.1 MB 99.1 MB/s eta 0:00:00:00:010:01
# Downloading tiktoken-0.6.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 59.4 MB/s eta 0:00:00
# Downloading boilerpy3-1.0.7-py3-none-any.whl (22 kB)
# Downloading Events-0.5-py3-none-any.whl (6.8 kB)
# Downloading farm_haystack-1.25.0-py3-none-any.whl (768 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 768.7/768.7 kB 43.5 MB/s eta 0:00:00
# Downloading posthog-3.5.0-py2.py3-none-any.whl (41 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.3/41.3 kB 2.4 MB/s eta 0:00:00
# Downloading quantulum3-0.9.0-py3-none-any.whl (10.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.7/10.7 MB 84.6 MB/s eta 0:00:00:00:010:01
# Downloading rank_bm25-0.2.2-py3-none-any.whl (8.6 kB)
# Downloading sseclient_py-1.8.0-py2.py3-none-any.whl (8.8 kB)
# Downloading cattrs-23.2.3-py3-none-any.whl (57 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.5/57.5 kB 3.8 MB/s eta 0:00:00
# Downloading monotonic-1.6-py2.py3-none-any.whl (8.2 kB)
# Downloading url_normalize-1.4.3-py2.py3-none-any.whl (6.8 kB)
# Downloading inflect-7.0.0-py3-none-any.whl (34 kB)
# Downloading num2words-0.5.13-py3-none-any.whl (143 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.3/143.3 kB 9.3 MB/s eta 0:00:00
# Installing collected packages: sseclient-py, monotonic, events, url-normalize, rank-bm25, pydantic, pillow, num2words, lazy-imports, cattrs, boilerpy3, tiktoken, scikit-learn, requests-cache, prompthub-py, posthog, inflect, quantulum3, transformers, farm-haystack
#   Attempting uninstall: pydantic
#     Found existing installation: pydantic 2.5.3
#     Uninstalling pydantic-2.5.3:
#       Successfully uninstalled pydantic-2.5.3
#   Attempting uninstall: pillow
#     Found existing installation: Pillow 9.5.0
#     Uninstalling Pillow-9.5.0:
#       Successfully uninstalled Pillow-9.5.0
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 1.2.2
#     Uninstalling scikit-learn-1.2.2:
#       Successfully uninstalled scikit-learn-1.2.2
#   Attempting uninstall: transformers
#     Found existing installation: transformers 4.38.1
#     Uninstalling transformers-4.38.1:
#       Successfully uninstalled transformers-4.38.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# scikit-image 0.22.0 requires pillow>=9.0.1, but you have pillow 9.0.0 which is incompatible.
# spopt 0.6.0 requires shapely>=2.0.1, but you have shapely 1.8.5.post1 which is incompatible.
# ydata-profiling 4.6.4 requires numpy<1.26,>=1.16.0, but you have numpy 1.26.4 which is incompatible.
# ydata-profiling 4.6.4 requires pydantic>=2, but you have pydantic 1.10.14 which is incompatible.
# Successfully installed boilerpy3-1.0.7 cattrs-23.2.3 events-0.5 farm-haystack-1.25.0 inflect-7.0.0 lazy-imports-0.3.1 monotonic-1.6 num2words-0.5.13 pillow-9.0.0 posthog-3.5.0 prompthub-py-4.0.0 pydantic-1.10.14 quantulum3-0.9.0 rank-bm25-0.2.2 requests-cache-0.9.8 scikit-learn-1.4.1.post1 sseclient-py-1.8.0 tiktoken-0.6.0 transformers-4.37.2 url-normalize-1.4.3
# Requirement already satisfied: datasets in /opt/conda/lib/python3.10/site-packages (2.1.0)
# Requirement already satisfied: numpy>=1.17 in /opt/conda/lib/python3.10/site-packages (from datasets) (1.26.4)
# Requirement already satisfied: pyarrow>=5.0.0 in /opt/conda/lib/python3.10/site-packages (from datasets) (11.0.0)
# Requirement already satisfied: dill in /opt/conda/lib/python3.10/site-packages (from datasets) (0.3.8)
# Requirement already satisfied: pandas in /opt/conda/lib/python3.10/site-packages (from datasets) (2.1.4)
# Requirement already satisfied: requests>=2.19.0 in /opt/conda/lib/python3.10/site-packages (from datasets) (2.31.0)
# Requirement already satisfied: tqdm>=4.62.1 in /opt/conda/lib/python3.10/site-packages (from datasets) (4.66.1)
# Requirement already satisfied: xxhash in /opt/conda/lib/python3.10/site-packages (from datasets) (3.4.1)
# Requirement already satisfied: multiprocess in /opt/conda/lib/python3.10/site-packages (from datasets) (0.70.16)
# Requirement already satisfied: fsspec>=2021.05.0 in /opt/conda/lib/python3.10/site-packages (from fsspec[http]>=2021.05.0->datasets) (2024.2.0)
# Requirement already satisfied: aiohttp in /opt/conda/lib/python3.10/site-packages (from datasets) (3.9.1)
# Requirement already satisfied: huggingface-hub<1.0.0,>=0.1.0 in /opt/conda/lib/python3.10/site-packages (from datasets) (0.20.3)
# Requirement already satisfied: packaging in /opt/conda/lib/python3.10/site-packages (from datasets) (21.3)
# Requirement already satisfied: responses<0.19 in /opt/conda/lib/python3.10/site-packages (from datasets) (0.18.0)
# Requirement already satisfied: attrs>=17.3.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp->datasets) (23.2.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /opt/conda/lib/python3.10/site-packages (from aiohttp->datasets) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp->datasets) (1.9.3)
# Requirement already satisfied: frozenlist>=1.1.1 in /opt/conda/lib/python3.10/site-packages (from aiohttp->datasets) (1.4.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /opt/conda/lib/python3.10/site-packages (from aiohttp->datasets) (1.3.1)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp->datasets) (4.0.3)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from huggingface-hub<1.0.0,>=0.1.0->datasets) (3.13.1)
# Requirement already satisfied: pyyaml>=5.1 in /opt/conda/lib/python3.10/site-packages (from huggingface-hub<1.0.0,>=0.1.0->datasets) (6.0.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /opt/conda/lib/python3.10/site-packages (from huggingface-hub<1.0.0,>=0.1.0->datasets) (4.9.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/conda/lib/python3.10/site-packages (from packaging->datasets) (3.1.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests>=2.19.0->datasets) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests>=2.19.0->datasets) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests>=2.19.0->datasets) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests>=2.19.0->datasets) (2024.2.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/lib/python3.10/site-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.10/site-packages (from pandas->datasets) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /opt/conda/lib/python3.10/site-packages (from pandas->datasets) (2023.4)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.16.0)

# %%
from datasets import load_dataset
data= load_dataset("climate_fever",split="test")
# Out:
# Downloading builder script:   0%|          | 0.00/2.01k [00:00<?, ?B/s]
# Downloading metadata:   0%|          | 0.00/1.06k [00:00<?, ?B/s]
# Downloading and preparing dataset climate_fever/default (download: 671.03 KiB, generated: 2.32 MiB, post-processed: Unknown size, total: 2.97 MiB) to /root/.cache/huggingface/datasets/climate_fever/default/1.0.1/60c6cf5ebdf73f1cad68b9a15e9da57d65e2d35416a13516080f6a0a34d8cbe6...
# Downloading data: 0.00B [00:00, ?B/s]
# Generating test split:   0%|          | 0/1535 [00:00<?, ? examples/s]
# Dataset climate_fever downloaded and prepared to /root/.cache/huggingface/datasets/climate_fever/default/1.0.1/60c6cf5ebdf73f1cad68b9a15e9da57d65e2d35416a13516080f6a0a34d8cbe6. Subsequent calls will reuse this data.

# %%
from haystack.document_stores import InMemoryDocumentStore

# Extract and format the documents from the dataset

documents = [{"content": x["claim"]} for x in data]

document_storage = InMemoryDocumentStore(use_bm25=True)

# Write the documents to the document store
document_storage.write_documents(documents)
# Out:
# 2024-03-20 15:29:15.570342: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-03-20 15:29:15.570445: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-03-20 15:29:15.702783: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-03-20 15:29:30,786	INFO util.py:124 -- Outdated packages:
#   ipywidgets==7.7.1 found, needs ipywidgets>=8
# Run `pip install -U ipywidgets`, then restart the notebook server for rich notebook output.
# Updating BM25 representation...: 100%|██████████| 1535/1535 [00:00<00:00, 82189.81 docs/s]

# %%
from haystack.nodes import BM25Retriever

# Note: The higher the top_k is, the better the answer will be. However, speed will be affected
retriever = BM25Retriever(document_store=document_storage, top_k=2)

# %%
from haystack.nodes import PromptNode, PromptTemplate, AnswerParser

rag_prompt = PromptTemplate(
    prompt="""Create comprehensive answers from the related text given the questions.
                             Provide a clear and concise response that displays the key points and information presented in the related text.
                             Your answer should be in your own words and be no longer than 50 words.
                             \n\n Related text: {join(documents)} \n\n Question: {query} \n\n Answer:""",
    output_parser=AnswerParser(),
)

prompt_node = PromptNode(model_name_or_path="google/flan-t5-large", default_prompt_template=rag_prompt)
# Out:
# config.json:   0%|          | 0.00/662 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/3.13G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/147 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/2.54k [00:00<?, ?B/s]
# spiece.model:   0%|          | 0.00/792k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/2.42M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/2.20k [00:00<?, ?B/s]

# %%
from haystack.pipelines import Pipeline

pipe = Pipeline()
pipe.add_node(component=retriever, name="retriever", inputs=["Query"])
pipe.add_node(component=prompt_node, name="prompt_node", inputs=["retriever"])

# %%
output = pipe.run(query="When did global warming start")
print(output["answers"][0].answer)
# Out:
# The 20th century global warming did not start until 1910.

# %%
# Here are some other examples you can use
examples = [
    "Who is most responsible for pollution",
    "What is the biggest damaging factor for the climate?",
    "What are some clean energy sources?",
    "How much does the average temperature of our planet rise per decade?"
]

# %%
for example in examples:
    output = pipe.run(query=example)
    question = f"\033[1;36mQuestion:\033[0m {example}"
    answer = f"\033[1;32mAnswer:\033[0m {output['answers'][0].answer}"
    print(f"{question}\n{answer}\n")
# Out:
# Question: Who is most responsible for pollution
# Answer: The IPCC 95% confidence that humans are responsible for most of the current global warming is simply a summary of the peer-reviewed scientific research.
#
# Question: What is the biggest damaging factor for the climate?
# Answer: Burping cows are more damaging to the climate than all the cars on this planet.
#
# Question: What are some clean energy sources?
# Answer: Solar, wind and geothermal.
#
# Question: How much does the average temperature of our planet rise per decade?
# Answer: The average temperature of our planet has risen by around 1.62F (0.9C).
